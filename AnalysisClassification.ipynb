# %%
import pandas as pd

#read dataset
df = pd.read_csv("brain_stroke.csv")

# %%
# Check for rows and columns
print("Rows, Cols:", df.shape)
# Out:
# Rows, Cols: (4981, 11)

# %%
# Check for Missing values per column
print("\nMissing values per column:")
print(df.isna().sum().sort_values(ascending=False))
# Out:
# Missing values per column:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
# show duplicate rows
dupe_count = df.duplicated().sum()
print("\nDuplicate rows:", dupe_count)
if dupe_count > 0:
    print("\nSample duplicate rows:")
    print(df[df.duplicated(keep=False)].head())
# Out:
# Duplicate rows: 0

# %%
# get all the v data type and total unique value
summary = pd.DataFrame({
    "dtype": df.dtypes.astype(str),
    "unique_values": df.nunique()
})
print("\nColumn summary (dtype + unique values):")
print(summary)
# Out:
# Column summary (dtype + unique values):
#                        dtype  unique_values
# ID                     int64           7500
# Age                    int64             52
# Gender                object              3
# Height_cm            float64            546
# Weight_kg            float64            771
# BMI                  float64            383
# Smoker                object              2
# Exercise_Freq         object              3
# Diet_Quality          object              4
# Alcohol_Consumption   object              3
# Chronic_Disease       object              2
# Stress_Level           int64             10
# Sleep_Hours          float64            102

# %%
#check all unique value for categarical data
cols = ["hypertension","heart_disease","ever_married",
        "work_type","Residence_type","smoking_status","stroke"]
uniques = {c: sorted(df[c].dropna().unique().tolist()) for c in cols}
for c, vals in uniques.items():
    print(f"{c}: {vals}")
# Out:
# hypertension: [0, 1]
# heart_disease: [0, 1]
# ever_married: ['No', 'Yes']
# work_type: ['Govt_job', 'Private', 'Self-employed', 'children']
# Residence_type: ['Rural', 'Urban']
# smoking_status: ['Unknown', 'formerly smoked', 'never smoked', 'smokes']
# stroke: [0, 1]
